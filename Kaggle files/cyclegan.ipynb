# %%
# !git config --global credential.helper 'store --file ~/.git-credentials'
# !echo "https://oauth2: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@github.com" > ~/.git-credentials
# !git clone https://github.com/andrea2399/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2987, done.
# remote: Total 2987 (delta 0), reused 0 (delta 0), pack-reused 2987 (from 1)
# Receiving objects: 100% (2987/2987), 8.33 MiB | 37.24 MiB/s, done.
# Resolving deltas: 100% (1911/1911), done.

# %%
# !ls pytorch-CycleGAN-and-pix2pix
import os
os.chdir('pytorch-CycleGAN-and-pix2pix')
# Out:
# CycleGAN.ipynb	data	  environment.yml  options	     scripts   util
# LICENSE		datasets  imgs		   pix2pix.ipynb     test.py
# README.md	docs	  models	   requirements.txt  train.py

# %%
# !ls ./checkpoints
# Out:
# ls: cannot access './checkpoints': No such file or directory

# %%
# !pip install -r requirements.txt

# %%
import wandb

# Sostituisci 'wandb_api_key' con il nome corretto del tuo segreto
wandb_api_key = "1be1b4683f8fc59c459aa5e46d1931ee8a0c7783"

# Accedi a W&B utilizzando la tua chiave API
wandb.login(key=wandb_api_key)

# %%
# !python train.py --dataroot /kaggle/input/train-final/train --name synthrad_brain_cbct2ct --model cycle_gan --batch_size 1 --n_epochs 60 --n_epochs_decay 0 --continue_train

# %%
# !ls ./checkpoints/synthrad_brain_cbct2ct
# Out:
# 5_net_D_A.pth  5_net_G_B.pth	   latest_net_G_A.pth  train_opt.txt
# 5_net_D_B.pth  latest_net_D_A.pth  latest_net_G_B.pth  web
# 5_net_G_A.pth  latest_net_D_B.pth  loss_log.txt

# %%
import shutil
import os

# Percorso della cartella di origine
source_folder = './checkpoints/synthrad_brain_cbct2ct'

# Percorso della cartella di destinazione
destination_folder = '/kaggle/working/checkpoints-cycle/synthrad_brain_cbct2ct/'

# Crea la cartella di destinazione se non esiste già
os.makedirs(destination_folder, exist_ok=True)

# Copia latest_net_G_A.pth nella nuova cartella
shutil.copyfile(os.path.join(source_folder, 'latest_net_G_A.pth'), os.path.join(destination_folder, 'latest_net_G_A.pth'))

# Copia latest_net_D_B.pth nella nuova cartella
shutil.copyfile(os.path.join(source_folder, 'latest_net_D_A.pth'), os.path.join(destination_folder, 'latest_net_D_A.pth'))

# Mostra il contenuto della cartella di destinazione
print("Contenuto della cartella di destinazione:")
print(os.listdir(destination_folder))

# %%
import os

# Percorso della cartella di destinazione
destination_folder = '/kaggle/working/checkpoints-cycle/synthrad_brain_cbct2ct/'

# Rinomina latest_net_G_A.pth a latest_net_G.pth
os.rename(os.path.join(destination_folder, 'latest_net_G_A.pth'), os.path.join(destination_folder, 'latest_net_G.pth'))

# Rinomina latest_net_D_B.pth a latest_net_D.pth
os.rename(os.path.join(destination_folder, 'latest_net_D_A.pth'), os.path.join(destination_folder, 'latest_net_D.pth'))

# Mostra il contenuto della cartella di destinazione
print("Contenuto della cartella di destinazione:")
print(os.listdir(destination_folder))

# %%
# !python test.py --dataroot /kaggle/input/test-cbct-final --results_dir /kaggle/working/brain_cyclegan_test_results --direction AtoB --model test --name synthrad_brain_cbct2ct --checkpoints_dir /kaggle/working/checkpoints-cycle --no_dropout --num_test 6150
#!python test.py --dataroot /kaggle/input/test-cbct-final --results_dir /kaggle/working/brain_cyclegan_test_results --direction AtoB --model test --name synthrad_brain_cbct2ct --checkpoints_dir ./checkpoints --no_dropout --num_test 6150
