# %%
# !rm ~/.git-credentials
# !git config --global credential.helper 'store --file ~/.git-credentials'
# !echo "https://oauth2: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@github.com" > ~/.git-credentials
# !git clone https://github.com/andrea2399/GLCIC-PyTorch

# %%
# !ls GLCIC-PyTorch
import os
os.chdir('GLCIC-PyTorch')
# !git checkout master

# %%
# !pip install -r requirements.txt

# %%
import shutil
import os
source_dataset_path = "/kaggle/input/nuovo-dataset1/Nuovo_Dataset1"
# Percorso della cartella datasets nel progetto GLCIC-PyTorch
destination_dataset_path = "/kaggle/working/GLCIC-PyTorch/datasets/"

# Elimina la cartella di destinazione esistente
shutil.rmtree(destination_dataset_path)#, ignore_errors=True)

# Copia il dataset nella cartella del progetto
shutil.copytree(source_dataset_path, destination_dataset_path)#
# Out:
# '/kaggle/working/GLCIC-PyTorch/datasets/'

# %%
# !python train.py /kaggle/working/GLCIC-PyTorch/datasets results/result/ --bsize 1 --steps_1 180000 --steps_2 20000 --steps_3 800000 --snaperiod_1 10000 --snaperiod_2 2000 --snaperiod_3 10000 --data_parallel

# %%
# !python predict.py /kaggle/working/GLCIC-PyTorch/results/result/phase_3/model_cn_latest /kaggle/working/GLCIC-PyTorch/results/result/config.json /kaggle/input/all-test-patients/All_test_patients/2BC090 /kaggle/working/GLCIC-PyTorch/images/2BC090_25 --max_holes 1 --img_size 291 --img_size_1 231 --hole_size 25 --hole_min_w 25 --hole_max_w 25 --hole_min_h 291 --hole_max_h 291
# Out:
# Output images were saved in /kaggle/working/GLCIC-PyTorch/images/2BC090_25.

# %%
import shutil
import os

# Define the source directory and the destination zip file
source_dir = '/kaggle/working/GLCIC-PyTorch/images/2BC090_25'
zip_filename = '/kaggle/working/2BC090_25_finale.zip'

# Create a zip file
shutil.make_archive(zip_filename.replace('.zip', ''), 'zip', source_dir)

print(f'Zip file created at {zip_filename}')
