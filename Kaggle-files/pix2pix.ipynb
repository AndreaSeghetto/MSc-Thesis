# %%
# !git config --global credential.helper 'store --file ~/.git-credentials'
# !echo "https://oauth2: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@github.com" > ~/.git-credentials
# !git clone https://github.com/andrea2399/pytorch-CycleGAN-and-pix2pix

# %%
# !ls pytorch-CycleGAN-and-pix2pix
import os
os.chdir('pytorch-CycleGAN-and-pix2pix')

# %%
# !pip install -r requirements.txt

# %%
import wandb

# Sostituisci 'wandb_api_key' con il nome corretto del tuo segreto
wandb_api_key = "1be1b4683f8fc59c459aa5e46d1931ee8a0c7783"

# Accedi a W&B utilizzando la tua chiave API
wandb.login(key=wandb_api_key)

# %%
# !python train.py --dataroot /kaggle/input/train-wlut/  --name synthrad_brain_cbct2ct --model pix2pix --batch_size 1 --n_epochs 60 --n_epochs_decay 0 --save_epoch_freq 5 --continue_train

# %%
# !ls ./checkpoints/synthrad_brain_cbct2ct

# %%
# !python test.py --dataroot /kaggle/input/test-inpainting --results_dir /kaggle/working/test_inpainting_final --direction AtoB --model pix2pix --name synthrad_brain_cbct2ct --checkpoints_dir ./checkpoints --num_test 6150

# %%
import shutil
import os

# Definisci il percorso della directory da comprimere
source_dir = '/kaggle/working/test_inpainting_final/synthrad_brain_cbct2ct'

# Definisci il percorso del file zip di destinazione
zip_file = '/kaggle/working/test_results_inpainting_final'

# Crea il file zip
shutil.make_archive(zip_file, 'zip', source_dir)

print(f'Successfully created zip file: {zip_file}.zip')
# Out:
# Successfully created zip file: /kaggle/working/test_results_inpainting_final.zip
